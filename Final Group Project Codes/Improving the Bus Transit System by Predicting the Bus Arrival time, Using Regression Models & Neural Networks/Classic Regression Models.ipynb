# %%
#Classic Regression Models on new york data set without normalizing the output, with merging latitude and longitude by h3-Uber function, to predict the **duration**
#Project Title: Improving the Bus Transit System by Predicting the Bus Arrival time, Using Regression Models and Neural Networks
# Group Members: Sanaz Hossseini, Shruthi Pasumarthi, Narges Rashvand

# %%
import os
import pandas as pd
import time
from datetime import datetime
import torch
import numpy as np
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch.nn as nn
import torch.nn.functional as F
torch.set_printoptions(edgeitems=2, linewidth=75)
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import torch.nn as nn
import pandas as pd

# %%
file = "MTA-1706-Edited-12112022.csv"
target_file = os.getcwd() + f"/{file}"

# %%
df = pd.read_csv(target_file)
df
# Out:
#      RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0           0:03:00  40.616104  -74.031143       40.656048       -73.907379
# 1           0:03:00  40.643169  -74.073494       40.575935       -74.167686
# 2           0:03:00  40.875008  -73.880142       40.912376       -73.902534
# 3           0:03:00  40.701748  -73.802399       40.666012       -73.735939
# 4           0:03:00  40.881187  -73.909340       40.809654       -73.928360
# ...             ...        ...         ...             ...              ...
# 9995        5:03:00  40.622311  -74.028687       40.640297       -74.131332
# 9996        5:03:00  40.761806  -73.829559       40.692406       -73.745216
# 9997        5:03:00  40.761806  -73.829559       40.692406       -73.745216
# 9998        5:03:00  40.862228  -73.890442       40.877934       -73.866585
# 9999        5:03:00  40.704906  -73.793304       40.784149       -73.845505
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 9995                 40.596955                 -74.069769              90.0
# 9996                 40.692326                 -73.744289             318.0
# 9997                 40.692326                 -73.744289             318.0
# 9998                 40.871502                 -73.876412             185.0
# 9999                 40.770012                 -73.826567               0.0
#
#      ExpectedArrivalTime ScheduledArrivalTime
# 0                0:03:00              0:06:14
# 1                0:03:00             23:58:02
# 2                0:03:00              0:00:53
# 3                0:04:00              0:03:00
# 4                0:03:00             23:59:38
# ...                  ...                  ...
# 9995             5:03:00              5:02:12
# 9996             5:04:00              4:22:13
# 9997             5:04:00              4:20:25
# 9998             5:03:00              5:01:25
# 9999             5:03:00              5:04:00
#
# [10000 rows x 10 columns]

# %%
df.dropna(axis = 0, how = 'any', thresh = None, subset = None, inplace = True) #The code, if we want to remove all the rows with empty cells.  
df
# Out:
#      RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0           0:03:00  40.616104  -74.031143       40.656048       -73.907379
# 1           0:03:00  40.643169  -74.073494       40.575935       -74.167686
# 2           0:03:00  40.875008  -73.880142       40.912376       -73.902534
# 3           0:03:00  40.701748  -73.802399       40.666012       -73.735939
# 4           0:03:00  40.881187  -73.909340       40.809654       -73.928360
# ...             ...        ...         ...             ...              ...
# 9995        5:03:00  40.622311  -74.028687       40.640297       -74.131332
# 9996        5:03:00  40.761806  -73.829559       40.692406       -73.745216
# 9997        5:03:00  40.761806  -73.829559       40.692406       -73.745216
# 9998        5:03:00  40.862228  -73.890442       40.877934       -73.866585
# 9999        5:03:00  40.704906  -73.793304       40.784149       -73.845505
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 9995                 40.596955                 -74.069769              90.0
# 9996                 40.692326                 -73.744289             318.0
# 9997                 40.692326                 -73.744289             318.0
# 9998                 40.871502                 -73.876412             185.0
# 9999                 40.770012                 -73.826567               0.0
#
#      ExpectedArrivalTime ScheduledArrivalTime
# 0                0:03:00              0:06:14
# 1                0:03:00             23:58:02
# 2                0:03:00              0:00:53
# 3                0:04:00              0:03:00
# 4                0:03:00             23:59:38
# ...                  ...                  ...
# 9995             5:03:00              5:02:12
# 9996             5:04:00              4:22:13
# 9997             5:04:00              4:20:25
# 9998             5:03:00              5:01:25
# 9999             5:03:00              5:04:00
#
# [8933 rows x 10 columns]

# %%
print(df.dtypes)
# Out:
# RecordedAtTime                object
# OriginLat                    float64
# OriginLong                   float64
# DestinationLat               float64
# DestinationLong              float64
# VehicleLocation.Latitude     float64
# VehicleLocation.Longitude    float64
# DistanceFromStop             float64
# ExpectedArrivalTime           object
# ScheduledArrivalTime          object
# dtype: object

# %%
print(df['RecordedAtTime'])
print(df['ExpectedArrivalTime'])
print(df['ScheduledArrivalTime'])
# Out:
# 0       0:03:00
# 1       0:03:00
# 2       0:03:00
# 3       0:03:00
# 4       0:03:00
#          ...
# 9995    5:03:00
# 9996    5:03:00
# 9997    5:03:00
# 9998    5:03:00
# 9999    5:03:00
# Name: RecordedAtTime, Length: 8933, dtype: object
# 0       0:03:00
# 1       0:03:00
# 2       0:03:00
# 3       0:04:00
# 4       0:03:00
#          ...
# 9995    5:03:00
# 9996    5:04:00
# 9997    5:04:00
# 9998    5:03:00
# 9999    5:03:00
# Name: ExpectedArrivalTime, Length: 8933, dtype: object
# 0        0:06:14
# 1       23:58:02
# 2        0:00:53
# 3        0:03:00
# 4       23:59:38
#           ...
# 9995     5:02:12
# 9996     4:22:13
# 9997     4:20:25
# 9998     5:01:25
# 9999     5:04:00
# Name: ScheduledArrivalTime, Length: 8933, dtype: object

# %%
df['RecordedAtTime'] = pd.to_datetime(df['RecordedAtTime'], errors = 'coerce')
tindex = pd.DatetimeIndex(df.RecordedAtTime) 
df['RecordedAtTime'] = tindex.strftime('%H:%M:%S')

# %%
df['RecordedAtTime'] = pd.to_timedelta(df['RecordedAtTime']).dt.total_seconds()
df['RecordedAtTime']
# Out:
# 0         180.0
# 1         180.0
# 2         180.0
# 3         180.0
# 4         180.0
#          ...
# 9995    18180.0
# 9996    18180.0
# 9997    18180.0
# 9998    18180.0
# 9999    18180.0
# Name: RecordedAtTime, Length: 8933, dtype: float64

# %%
df['ExpectedArrivalTime'] = pd.to_datetime(df['ExpectedArrivalTime'], errors = 'coerce')
tindex2 = pd.DatetimeIndex(df.ExpectedArrivalTime) 
df['ExpectedArrivalTime'] = tindex2.strftime('%H:%M:%S')

# %%
df['ExpectedArrivalTime'] = pd.to_timedelta(df['ExpectedArrivalTime']).dt.total_seconds()
df['ExpectedArrivalTime']
# Out:
# 0         180.0
# 1         180.0
# 2         180.0
# 3         240.0
# 4         180.0
#          ...
# 9995    18180.0
# 9996    18240.0
# 9997    18240.0
# 9998    18180.0
# 9999    18180.0
# Name: ExpectedArrivalTime, Length: 8933, dtype: float64

# %%
df['ScheduledArrivalTime'] = pd.to_datetime(df['ScheduledArrivalTime'], errors = 'coerce')
tindex3 = pd.DatetimeIndex(df.ScheduledArrivalTime) 
df['ScheduledArrivalTime'] = tindex3.strftime('%H:%M:%S')

# %%
df['ScheduledArrivalTime'] = pd.to_timedelta(df['ScheduledArrivalTime']).dt.total_seconds()
df['ScheduledArrivalTime']
# Out:
# 0         374.0
# 1       86282.0
# 2          53.0
# 3         180.0
# 4       86378.0
#          ...
# 9995    18132.0
# 9996    15733.0
# 9997    15625.0
# 9998    18085.0
# 9999    18240.0
# Name: ScheduledArrivalTime, Length: 8933, dtype: float64

# %%
df
# Out:
#       RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0              180.0  40.616104  -74.031143       40.656048       -73.907379
# 1              180.0  40.643169  -74.073494       40.575935       -74.167686
# 2              180.0  40.875008  -73.880142       40.912376       -73.902534
# 3              180.0  40.701748  -73.802399       40.666012       -73.735939
# 4              180.0  40.881187  -73.909340       40.809654       -73.928360
# ...              ...        ...         ...             ...              ...
# 9995         18180.0  40.622311  -74.028687       40.640297       -74.131332
# 9996         18180.0  40.761806  -73.829559       40.692406       -73.745216
# 9997         18180.0  40.761806  -73.829559       40.692406       -73.745216
# 9998         18180.0  40.862228  -73.890442       40.877934       -73.866585
# 9999         18180.0  40.704906  -73.793304       40.784149       -73.845505
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 9995                 40.596955                 -74.069769              90.0
# 9996                 40.692326                 -73.744289             318.0
# 9997                 40.692326                 -73.744289             318.0
# 9998                 40.871502                 -73.876412             185.0
# 9999                 40.770012                 -73.826567               0.0
#
#       ExpectedArrivalTime  ScheduledArrivalTime
# 0                   180.0                 374.0
# 1                   180.0               86282.0
# 2                   180.0                  53.0
# 3                   240.0                 180.0
# 4                   180.0               86378.0
# ...                   ...                   ...
# 9995              18180.0               18132.0
# 9996              18240.0               15733.0
# 9997              18240.0               15625.0
# 9998              18180.0               18085.0
# 9999              18180.0               18240.0
#
# [8933 rows x 10 columns]

# %%
print(df.dtypes)
# Out:
# RecordedAtTime               float64
# OriginLat                    float64
# OriginLong                   float64
# DestinationLat               float64
# DestinationLong              float64
# VehicleLocation.Latitude     float64
# VehicleLocation.Longitude    float64
# DistanceFromStop             float64
# ExpectedArrivalTime          float64
# ScheduledArrivalTime         float64
# dtype: object

# %%
l = df.shape[0]

# %%
arr = df.to_numpy()

# %%
import h3
origin_vehicle = np.zeros(l)

vehicle_destination = np.zeros(l)

for i in range(l):

    coords_1 = (arr[i, 1], arr[i, 2])

    coords_2 = (arr[i,5], arr[i,6])  

    origin_vehicle[i] = h3.point_dist(coords_1, coords_2, unit = 'm')
    
    coords_3 = (arr[i, 3], arr[i, 4])

    coords_4 = (arr[i,5], arr[i,6])

    vehicle_destination[i] = h3.point_dist(coords_1, coords_2, unit = 'm')

# %%
o = pd.DataFrame(origin_vehicle, columns = ['O_V'])

vd = pd.DataFrame(vehicle_destination, columns = ['V_D'])

# %%
df['O_V'] = o

df['V_D'] = vd

# %%
df
# Out:
#       RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0              180.0  40.616104  -74.031143       40.656048       -73.907379
# 1              180.0  40.643169  -74.073494       40.575935       -74.167686
# 2              180.0  40.875008  -73.880142       40.912376       -73.902534
# 3              180.0  40.701748  -73.802399       40.666012       -73.735939
# 4              180.0  40.881187  -73.909340       40.809654       -73.928360
# ...              ...        ...         ...             ...              ...
# 9995         18180.0  40.622311  -74.028687       40.640297       -74.131332
# 9996         18180.0  40.761806  -73.829559       40.692406       -73.745216
# 9997         18180.0  40.761806  -73.829559       40.692406       -73.745216
# 9998         18180.0  40.862228  -73.890442       40.877934       -73.866585
# 9999         18180.0  40.704906  -73.793304       40.784149       -73.845505
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 9995                 40.596955                 -74.069769              90.0
# 9996                 40.692326                 -73.744289             318.0
# 9997                 40.692326                 -73.744289             318.0
# 9998                 40.871502                 -73.876412             185.0
# 9999                 40.770012                 -73.826567               0.0
#
#       ExpectedArrivalTime  ScheduledArrivalTime          O_V          V_D
# 0                   180.0                 374.0  6303.540673  6303.540673
# 1                   180.0               86282.0  9230.043179  9230.043179
# 2                   180.0                  53.0  2994.093405  2994.093405
# 3                   240.0                 180.0  7212.611156  7212.611156
# 4                   180.0               86378.0  1996.682927  1996.682927
# ...                   ...                   ...          ...          ...
# 9995              18180.0               18132.0          NaN          NaN
# 9996              18240.0               15733.0          NaN          NaN
# 9997              18240.0               15625.0          NaN          NaN
# 9998              18180.0               18085.0          NaN          NaN
# 9999              18180.0               18240.0          NaN          NaN
#
# [8933 rows x 12 columns]

# %%
df.dropna(axis = 0, how = 'any', thresh = None, subset = None, inplace = True) #The code, if we want to remove all the rows with empty cells.  
df
# Out:
#       RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0              180.0  40.616104  -74.031143       40.656048       -73.907379
# 1              180.0  40.643169  -74.073494       40.575935       -74.167686
# 2              180.0  40.875008  -73.880142       40.912376       -73.902534
# 3              180.0  40.701748  -73.802399       40.666012       -73.735939
# 4              180.0  40.881187  -73.909340       40.809654       -73.928360
# ...              ...        ...         ...             ...              ...
# 8928         16440.0  40.861012  -73.890450       40.816143       -73.917549
# 8929         16380.0  40.642979  -73.878334       40.576973       -73.981400
# 8930         16380.0  40.642979  -73.878334       40.576973       -73.981400
# 8931         16380.0  40.586937  -74.086418       40.643570       -74.073227
# 8932         16380.0  40.619526  -73.933342       40.663013       -73.962212
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 8928                 40.860429                 -73.890861             160.0
# 8929                 40.620067                 -73.941519             158.0
# 8930                 40.620067                 -73.941519             158.0
# 8931                 40.621926                 -74.078227              43.0
# 8932                 40.649651                 -73.958527             145.0
#
#       ExpectedArrivalTime  ScheduledArrivalTime           O_V           V_D
# 0                   180.0                 374.0   6303.540673   6303.540673
# 1                   180.0               86282.0   9230.043179   9230.043179
# 2                   180.0                  53.0   2994.093405   2994.093405
# 3                   240.0                 180.0   7212.611156   7212.611156
# 4                   180.0               86378.0   1996.682927   1996.682927
# ...                   ...                   ...           ...           ...
# 8928              16440.0               16839.0   4469.447811   4469.447811
# 8929              16440.0               16558.0  10550.759498  10550.759498
# 8930              16440.0               16556.0  10550.759498  10550.759498
# 8931              16440.0               16282.0   1566.934347   1566.934347
# 8932              16440.0               16320.0   7762.987031   7762.987031
#
# [7959 rows x 12 columns]

# %%
df['delay']=abs(df['ExpectedArrivalTime'] - df['ScheduledArrivalTime'])
df
# Out:
#       RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0              180.0  40.616104  -74.031143       40.656048       -73.907379
# 1              180.0  40.643169  -74.073494       40.575935       -74.167686
# 2              180.0  40.875008  -73.880142       40.912376       -73.902534
# 3              180.0  40.701748  -73.802399       40.666012       -73.735939
# 4              180.0  40.881187  -73.909340       40.809654       -73.928360
# ...              ...        ...         ...             ...              ...
# 8928         16440.0  40.861012  -73.890450       40.816143       -73.917549
# 8929         16380.0  40.642979  -73.878334       40.576973       -73.981400
# 8930         16380.0  40.642979  -73.878334       40.576973       -73.981400
# 8931         16380.0  40.586937  -74.086418       40.643570       -74.073227
# 8932         16380.0  40.619526  -73.933342       40.663013       -73.962212
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 8928                 40.860429                 -73.890861             160.0
# 8929                 40.620067                 -73.941519             158.0
# 8930                 40.620067                 -73.941519             158.0
# 8931                 40.621926                 -74.078227              43.0
# 8932                 40.649651                 -73.958527             145.0
#
#       ExpectedArrivalTime  ScheduledArrivalTime           O_V           V_D  \
# 0                   180.0                 374.0   6303.540673   6303.540673
# 1                   180.0               86282.0   9230.043179   9230.043179
# 2                   180.0                  53.0   2994.093405   2994.093405
# 3                   240.0                 180.0   7212.611156   7212.611156
# 4                   180.0               86378.0   1996.682927   1996.682927
# ...                   ...                   ...           ...           ...
# 8928              16440.0               16839.0   4469.447811   4469.447811
# 8929              16440.0               16558.0  10550.759498  10550.759498
# 8930              16440.0               16556.0  10550.759498  10550.759498
# 8931              16440.0               16282.0   1566.934347   1566.934347
# 8932              16440.0               16320.0   7762.987031   7762.987031
#
#         delay
# 0       194.0
# 1     86102.0
# 2       127.0
# 3        60.0
# 4     86198.0
# ...       ...
# 8928    399.0
# 8929    118.0
# 8930    116.0
# 8931    158.0
# 8932    120.0
#
# [7959 rows x 13 columns]

# %%
df['duration']=abs(df['ExpectedArrivalTime'] - df['RecordedAtTime'])
df
# Out:
#       RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0              180.0  40.616104  -74.031143       40.656048       -73.907379
# 1              180.0  40.643169  -74.073494       40.575935       -74.167686
# 2              180.0  40.875008  -73.880142       40.912376       -73.902534
# 3              180.0  40.701748  -73.802399       40.666012       -73.735939
# 4              180.0  40.881187  -73.909340       40.809654       -73.928360
# ...              ...        ...         ...             ...              ...
# 8928         16440.0  40.861012  -73.890450       40.816143       -73.917549
# 8929         16380.0  40.642979  -73.878334       40.576973       -73.981400
# 8930         16380.0  40.642979  -73.878334       40.576973       -73.981400
# 8931         16380.0  40.586937  -74.086418       40.643570       -74.073227
# 8932         16380.0  40.619526  -73.933342       40.663013       -73.962212
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 8928                 40.860429                 -73.890861             160.0
# 8929                 40.620067                 -73.941519             158.0
# 8930                 40.620067                 -73.941519             158.0
# 8931                 40.621926                 -74.078227              43.0
# 8932                 40.649651                 -73.958527             145.0
#
#       ExpectedArrivalTime  ScheduledArrivalTime           O_V           V_D  \
# 0                   180.0                 374.0   6303.540673   6303.540673
# 1                   180.0               86282.0   9230.043179   9230.043179
# 2                   180.0                  53.0   2994.093405   2994.093405
# 3                   240.0                 180.0   7212.611156   7212.611156
# 4                   180.0               86378.0   1996.682927   1996.682927
# ...                   ...                   ...           ...           ...
# 8928              16440.0               16839.0   4469.447811   4469.447811
# 8929              16440.0               16558.0  10550.759498  10550.759498
# 8930              16440.0               16556.0  10550.759498  10550.759498
# 8931              16440.0               16282.0   1566.934347   1566.934347
# 8932              16440.0               16320.0   7762.987031   7762.987031
#
#         delay  duration
# 0       194.0       0.0
# 1     86102.0       0.0
# 2       127.0       0.0
# 3        60.0      60.0
# 4     86198.0       0.0
# ...       ...       ...
# 8928    399.0       0.0
# 8929    118.0      60.0
# 8930    116.0      60.0
# 8931    158.0      60.0
# 8932    120.0      60.0
#
# [7959 rows x 14 columns]

# %%
df["DistanceFromStop"] = pd.to_numeric(df["DistanceFromStop"], errors='coerce').fillna(0, downcast='infer')

# %%
print(df.dtypes)
# Out:
# RecordedAtTime               float64
# OriginLat                    float64
# OriginLong                   float64
# DestinationLat               float64
# DestinationLong              float64
# VehicleLocation.Latitude     float64
# VehicleLocation.Longitude    float64
# DistanceFromStop               int64
# ExpectedArrivalTime          float64
# ScheduledArrivalTime         float64
# O_V                          float64
# V_D                          float64
# delay                        float64
# duration                     float64
# dtype: object

# %%
variables = ['RecordedAtTime','DistanceFromStop', 'O_V', 'V_D', 'ExpectedArrivalTime', 'ScheduledArrivalTime', 'delay', 'duration']
df_new = df[variables]
df_new.head()
# Out:
#    RecordedAtTime  DistanceFromStop          O_V          V_D  \
# 0           180.0                76  6303.540673  6303.540673
# 1           180.0                62  9230.043179  9230.043179
# 2           180.0                 5  2994.093405  2994.093405
# 3           180.0               267  7212.611156  7212.611156
# 4           180.0                11  1996.682927  1996.682927
#
#    ExpectedArrivalTime  ScheduledArrivalTime    delay  duration
# 0                180.0                 374.0    194.0       0.0
# 1                180.0               86282.0  86102.0       0.0
# 2                180.0                  53.0    127.0       0.0
# 3                240.0                 180.0     60.0      60.0
# 4                180.0               86378.0  86198.0       0.0

# %%
df_new
# Out:
#       RecordedAtTime  DistanceFromStop           O_V           V_D  \
# 0              180.0                76   6303.540673   6303.540673
# 1              180.0                62   9230.043179   9230.043179
# 2              180.0                 5   2994.093405   2994.093405
# 3              180.0               267   7212.611156   7212.611156
# 4              180.0                11   1996.682927   1996.682927
# ...              ...               ...           ...           ...
# 8928         16440.0               160   4469.447811   4469.447811
# 8929         16380.0               158  10550.759498  10550.759498
# 8930         16380.0               158  10550.759498  10550.759498
# 8931         16380.0                43   1566.934347   1566.934347
# 8932         16380.0               145   7762.987031   7762.987031
#
#       ExpectedArrivalTime  ScheduledArrivalTime    delay  duration
# 0                   180.0                 374.0    194.0       0.0
# 1                   180.0               86282.0  86102.0       0.0
# 2                   180.0                  53.0    127.0       0.0
# 3                   240.0                 180.0     60.0      60.0
# 4                   180.0               86378.0  86198.0       0.0
# ...                   ...                   ...      ...       ...
# 8928              16440.0               16839.0    399.0       0.0
# 8929              16440.0               16558.0    118.0      60.0
# 8930              16440.0               16556.0    116.0      60.0
# 8931              16440.0               16282.0    158.0      60.0
# 8932              16440.0               16320.0    120.0      60.0
#
# [7959 rows x 8 columns]

# %%
X = df_new.iloc[:, 1:4].values
Y = df_new.iloc[:, 7].values
Y
# Out:
# array([ 0.,  0.,  0., ..., 60., 60., 60.])

# %%
Y.shape
# Out:
# (7959,)

# %%
X.shape
# Out:
# (7959, 3)

# %%
X
# Out:
# array([[7.60000000e+01, 6.30354067e+03, 6.30354067e+03],
#        [6.20000000e+01, 9.23004318e+03, 9.23004318e+03],
#        [5.00000000e+00, 2.99409341e+03, 2.99409341e+03],
#        ...,
#        [1.58000000e+02, 1.05507595e+04, 1.05507595e+04],
#        [4.30000000e+01, 1.56693435e+03, 1.56693435e+03],
#        [1.45000000e+02, 7.76298703e+03, 7.76298703e+03]])

# %%
scaler = MinMaxScaler()
X= scaler.fit_transform(X)
X
# Out:
# array([[0.00831783, 0.20282799, 0.20282799],
#        [0.0067856 , 0.29707273, 0.29707273],
#        [0.00054723, 0.09625094, 0.09625094],
#        ...,
#        [0.01729233, 0.33960492, 0.33960492],
#        [0.00470614, 0.05029087, 0.05029087],
#        [0.01586954, 0.24982783, 0.24982783]])

# %%
X = torch.tensor(X)
Y = torch.tensor(Y)
X.shape
# Out:
# torch.Size([7959, 3])

# %%
n_samples = X.shape[0]
n_val = int(0.2 * n_samples)

shuffled_indices = torch.randperm(n_samples)

train_indices = shuffled_indices[:-n_val]
val_indices = shuffled_indices[-n_val:]

train_X = X[train_indices]
train_Y = Y[train_indices]
#train_Y = train_Y.unsqueeze(1)

val_X = X[val_indices]
val_Y = Y[val_indices]
#val_Y = val_Y.unsqueeze(1)

# %%
print(train_X.shape)
print(train_Y.shape)
print(val_X.shape)
print(val_Y.shape)
# Out:
# torch.Size([6368, 3])
# torch.Size([6368])
# torch.Size([1591, 3])
# torch.Size([1591])

# %%
train_X = train_X.float()
train_Y = train_Y.float()
val_X = val_X.float()
val_Y = val_Y.float()
print(train_X.dtype)
print(train_Y.dtype)
print(val_X.dtype)
print(val_Y.dtype)
# Out:
# torch.float32
# torch.float32
# torch.float32
# torch.float32

# %%
#def MAPE(val_Y,yfit):
#    mape = np.mean(np.abs((val_Y - yfit)/val_Y))*100
#    return mape

# %%
#from sklearn.metrics import mean_squared_error
#from math import sqrt
#y_predicted = xgb.predict(train_X)
#rms = sqrt(mean_squared_error(train_Y, y_predicted))
#print("RMSE:", rms)

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
X, y = make_regression(n_features=3, n_informative=2, random_state=0, shuffle=False)
regr = RandomForestRegressor(max_depth=2, random_state=0)
yfit = regr.fit(train_X,train_Y)
#yfit_r = R.predict(X_test)
score = regr.score(train_X,train_Y)
print("Score: ",score)
from sklearn.metrics import mean_squared_error
from math import sqrt
y_predicted = regr.predict(train_X)
rms = sqrt(mean_squared_error(train_Y, y_predicted))
print("RMSE:", rms)
# Out:
# Score:  0.49711336041623766
# RMSE: 37.653040861122015

# %%
from sklearn import linear_model
lasso = linear_model.Lasso(alpha=0.1)
fit_Y = lasso.fit(train_X, train_Y)
score = lasso.score(train_X,train_Y)
print("Score: ",score)
from sklearn.metrics import mean_squared_error
from math import sqrt
y_predicted = lasso.predict(train_X)
rms = sqrt(mean_squared_error(train_Y, y_predicted))
print("RMSE:", rms)
# Out:
# Score:  0.46578054293537596
# RMSE: 38.808321330647175

# %%
from sklearn import ensemble
params = {'n_estimators': 500, 'max_depth':4, 'min_samples_split': 2,'learning_rate': 0.01, 'loss': 'ls'}
gb = ensemble.GradientBoostingRegressor(**params)
fit_Y = gb.fit(train_X, train_Y)
score = gb.score(train_X, train_Y)
print("Score: ", score)
from sklearn.metrics import mean_squared_error
from math import sqrt
y_predicted = gb.predict(train_X)
rms = sqrt(mean_squared_error(train_Y, y_predicted))
print("RMSE:", rms)
# Out:
# C:\Users\Sanaz\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
# Score:  0.5892889963991657
# RMSE: 34.02774550044855

# %%
#!pip install xgboost - run this command first to install the xgboost package from anaconda
import xgboost
from xgboost import XGBRegressor
xgb = XGBRegressor(n_estimators=1000, learning_rate=0.05,n_jobs=4)
fit_Y = xgb.fit(train_X, train_Y, early_stopping_rounds=5, eval_set=[(train_X, train_Y)], verbose=False)
score = xgb.score(train_X, train_Y)
print("Score: ", score)
from sklearn.metrics import mean_squared_error
from math import sqrt
y_predicted = xgb.predict(train_X)
rms = sqrt(mean_squared_error(train_Y, y_predicted))
print("RMSE:", rms)
# Out:
# C:\Users\Sanaz\anaconda3\lib\site-packages\xgboost\sklearn.py:861: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# Score:  0.8397806134459525
# RMSE: 21.253112565014373

# %%
from sklearn.linear_model import Ridge
import numpy as np
n_samples, n_features = 7959, 3
rng = np.random.RandomState(0)
train_Y = rng.randn(n_samples)
train_X = rng.randn(n_samples, n_features)
rdg = Ridge(alpha=1.0)
fit_Y = rdg.fit(train_X, train_Y)
score = rdg.score(train_X, train_Y)
print("Score: ", score)
from sklearn.metrics import mean_squared_error
from math import sqrt
y_predicted = rdg.predict(train_X)
rms = sqrt(mean_squared_error(train_Y, y_predicted))
print("RMSE:", rms)
# Out:
# Score:  0.0001477535476394065
# RMSE: 0.9869579698344455
