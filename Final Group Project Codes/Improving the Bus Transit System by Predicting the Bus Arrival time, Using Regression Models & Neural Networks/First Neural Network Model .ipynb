# %%
#NN on new york data set without normalizing the output and without merging latitudes and longitudes to predict the **duration** 
#Project Title: Improving the Bus Transit System by Predicting the Bus Arrival time, Using Regression Models and Neural Networks
# Group Members: Sanaz Hossseini, Shruthi Pasumarthi, Narges Rashvand

# %%
import os
import time
from datetime import datetime
import torch
import numpy as np
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch.nn as nn
import torch.nn.functional as F
torch.set_printoptions(edgeitems=2, linewidth=75)
import math

import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
file = "MTA-1706-Edited-12112022.csv"
target_file = os.getcwd() + f"/{file}"

# %%
df = pd.read_csv(target_file)
df
# Out:
#      RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0           0:03:00  40.616104  -74.031143       40.656048       -73.907379
# 1           0:03:00  40.643169  -74.073494       40.575935       -74.167686
# 2           0:03:00  40.875008  -73.880142       40.912376       -73.902534
# 3           0:03:00  40.701748  -73.802399       40.666012       -73.735939
# 4           0:03:00  40.881187  -73.909340       40.809654       -73.928360
# ...             ...        ...         ...             ...              ...
# 9995        5:03:00  40.622311  -74.028687       40.640297       -74.131332
# 9996        5:03:00  40.761806  -73.829559       40.692406       -73.745216
# 9997        5:03:00  40.761806  -73.829559       40.692406       -73.745216
# 9998        5:03:00  40.862228  -73.890442       40.877934       -73.866585
# 9999        5:03:00  40.704906  -73.793304       40.784149       -73.845505
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 9995                 40.596955                 -74.069769              90.0
# 9996                 40.692326                 -73.744289             318.0
# 9997                 40.692326                 -73.744289             318.0
# 9998                 40.871502                 -73.876412             185.0
# 9999                 40.770012                 -73.826567               0.0
#
#      ExpectedArrivalTime ScheduledArrivalTime
# 0                0:03:00              0:06:14
# 1                0:03:00             23:58:02
# 2                0:03:00              0:00:53
# 3                0:04:00              0:03:00
# 4                0:03:00             23:59:38
# ...                  ...                  ...
# 9995             5:03:00              5:02:12
# 9996             5:04:00              4:22:13
# 9997             5:04:00              4:20:25
# 9998             5:03:00              5:01:25
# 9999             5:03:00              5:04:00
#
# [10000 rows x 10 columns]

# %%
df.dropna(axis = 0, how = 'any', thresh = None, subset = None, inplace = True) #The code, if we want to remove all the rows with empty cells.  
df
# Out:
#      RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0           0:03:00  40.616104  -74.031143       40.656048       -73.907379
# 1           0:03:00  40.643169  -74.073494       40.575935       -74.167686
# 2           0:03:00  40.875008  -73.880142       40.912376       -73.902534
# 3           0:03:00  40.701748  -73.802399       40.666012       -73.735939
# 4           0:03:00  40.881187  -73.909340       40.809654       -73.928360
# ...             ...        ...         ...             ...              ...
# 9995        5:03:00  40.622311  -74.028687       40.640297       -74.131332
# 9996        5:03:00  40.761806  -73.829559       40.692406       -73.745216
# 9997        5:03:00  40.761806  -73.829559       40.692406       -73.745216
# 9998        5:03:00  40.862228  -73.890442       40.877934       -73.866585
# 9999        5:03:00  40.704906  -73.793304       40.784149       -73.845505
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 9995                 40.596955                 -74.069769              90.0
# 9996                 40.692326                 -73.744289             318.0
# 9997                 40.692326                 -73.744289             318.0
# 9998                 40.871502                 -73.876412             185.0
# 9999                 40.770012                 -73.826567               0.0
#
#      ExpectedArrivalTime ScheduledArrivalTime
# 0                0:03:00              0:06:14
# 1                0:03:00             23:58:02
# 2                0:03:00              0:00:53
# 3                0:04:00              0:03:00
# 4                0:03:00             23:59:38
# ...                  ...                  ...
# 9995             5:03:00              5:02:12
# 9996             5:04:00              4:22:13
# 9997             5:04:00              4:20:25
# 9998             5:03:00              5:01:25
# 9999             5:03:00              5:04:00
#
# [8933 rows x 10 columns]

# %%
print(df.dtypes)
# Out:
# RecordedAtTime                object
# OriginLat                    float64
# OriginLong                   float64
# DestinationLat               float64
# DestinationLong              float64
# VehicleLocation.Latitude     float64
# VehicleLocation.Longitude    float64
# DistanceFromStop             float64
# ExpectedArrivalTime           object
# ScheduledArrivalTime          object
# dtype: object

# %%
print(df['RecordedAtTime'])
print(df['ExpectedArrivalTime'])
print(df['ScheduledArrivalTime'])
# Out:
# 0       0:03:00
# 1       0:03:00
# 2       0:03:00
# 3       0:03:00
# 4       0:03:00
#          ...
# 9995    5:03:00
# 9996    5:03:00
# 9997    5:03:00
# 9998    5:03:00
# 9999    5:03:00
# Name: RecordedAtTime, Length: 8933, dtype: object
# 0       0:03:00
# 1       0:03:00
# 2       0:03:00
# 3       0:04:00
# 4       0:03:00
#          ...
# 9995    5:03:00
# 9996    5:04:00
# 9997    5:04:00
# 9998    5:03:00
# 9999    5:03:00
# Name: ExpectedArrivalTime, Length: 8933, dtype: object
# 0        0:06:14
# 1       23:58:02
# 2        0:00:53
# 3        0:03:00
# 4       23:59:38
#           ...
# 9995     5:02:12
# 9996     4:22:13
# 9997     4:20:25
# 9998     5:01:25
# 9999     5:04:00
# Name: ScheduledArrivalTime, Length: 8933, dtype: object

# %%
df['RecordedAtTime'] = pd.to_datetime(df['RecordedAtTime'], errors = 'coerce')
tindex = pd.DatetimeIndex(df.RecordedAtTime) 
df['RecordedAtTime'] = tindex.strftime('%H:%M:%S')

# %%
df['RecordedAtTime'] = pd.to_timedelta(df['RecordedAtTime']).dt.total_seconds()
df['RecordedAtTime']
# Out:
# 0         180.0
# 1         180.0
# 2         180.0
# 3         180.0
# 4         180.0
#          ...
# 9995    18180.0
# 9996    18180.0
# 9997    18180.0
# 9998    18180.0
# 9999    18180.0
# Name: RecordedAtTime, Length: 8933, dtype: float64

# %%
df['ExpectedArrivalTime'] = pd.to_datetime(df['ExpectedArrivalTime'], errors = 'coerce')
tindex2 = pd.DatetimeIndex(df.ExpectedArrivalTime) 
df['ExpectedArrivalTime'] = tindex2.strftime('%H:%M:%S')

# %%
df['ExpectedArrivalTime'] = pd.to_timedelta(df['ExpectedArrivalTime']).dt.total_seconds()
df['ExpectedArrivalTime']
# Out:
# 0         180.0
# 1         180.0
# 2         180.0
# 3         240.0
# 4         180.0
#          ...
# 9995    18180.0
# 9996    18240.0
# 9997    18240.0
# 9998    18180.0
# 9999    18180.0
# Name: ExpectedArrivalTime, Length: 8933, dtype: float64

# %%
df['ScheduledArrivalTime'] = pd.to_datetime(df['ScheduledArrivalTime'], errors = 'coerce')
tindex3 = pd.DatetimeIndex(df.ScheduledArrivalTime) 
df['ScheduledArrivalTime'] = tindex3.strftime('%H:%M:%S')

# %%
df['ScheduledArrivalTime'] = pd.to_timedelta(df['ScheduledArrivalTime']).dt.total_seconds()
df['ScheduledArrivalTime']
# Out:
# 0         374.0
# 1       86282.0
# 2          53.0
# 3         180.0
# 4       86378.0
#          ...
# 9995    18132.0
# 9996    15733.0
# 9997    15625.0
# 9998    18085.0
# 9999    18240.0
# Name: ScheduledArrivalTime, Length: 8933, dtype: float64

# %%
df
# Out:
#       RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0              180.0  40.616104  -74.031143       40.656048       -73.907379
# 1              180.0  40.643169  -74.073494       40.575935       -74.167686
# 2              180.0  40.875008  -73.880142       40.912376       -73.902534
# 3              180.0  40.701748  -73.802399       40.666012       -73.735939
# 4              180.0  40.881187  -73.909340       40.809654       -73.928360
# ...              ...        ...         ...             ...              ...
# 9995         18180.0  40.622311  -74.028687       40.640297       -74.131332
# 9996         18180.0  40.761806  -73.829559       40.692406       -73.745216
# 9997         18180.0  40.761806  -73.829559       40.692406       -73.745216
# 9998         18180.0  40.862228  -73.890442       40.877934       -73.866585
# 9999         18180.0  40.704906  -73.793304       40.784149       -73.845505
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 9995                 40.596955                 -74.069769              90.0
# 9996                 40.692326                 -73.744289             318.0
# 9997                 40.692326                 -73.744289             318.0
# 9998                 40.871502                 -73.876412             185.0
# 9999                 40.770012                 -73.826567               0.0
#
#       ExpectedArrivalTime  ScheduledArrivalTime
# 0                   180.0                 374.0
# 1                   180.0               86282.0
# 2                   180.0                  53.0
# 3                   240.0                 180.0
# 4                   180.0               86378.0
# ...                   ...                   ...
# 9995              18180.0               18132.0
# 9996              18240.0               15733.0
# 9997              18240.0               15625.0
# 9998              18180.0               18085.0
# 9999              18180.0               18240.0
#
# [8933 rows x 10 columns]

# %%
print(df.dtypes)
# Out:
# RecordedAtTime               float64
# OriginLat                    float64
# OriginLong                   float64
# DestinationLat               float64
# DestinationLong              float64
# VehicleLocation.Latitude     float64
# VehicleLocation.Longitude    float64
# DistanceFromStop             float64
# ExpectedArrivalTime          float64
# ScheduledArrivalTime         float64
# dtype: object

# %%
df['duration']=abs(df['ExpectedArrivalTime'] - df['RecordedAtTime'])
df
# Out:
#       RecordedAtTime  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0              180.0  40.616104  -74.031143       40.656048       -73.907379
# 1              180.0  40.643169  -74.073494       40.575935       -74.167686
# 2              180.0  40.875008  -73.880142       40.912376       -73.902534
# 3              180.0  40.701748  -73.802399       40.666012       -73.735939
# 4              180.0  40.881187  -73.909340       40.809654       -73.928360
# ...              ...        ...         ...             ...              ...
# 9995         18180.0  40.622311  -74.028687       40.640297       -74.131332
# 9996         18180.0  40.761806  -73.829559       40.692406       -73.745216
# 9997         18180.0  40.761806  -73.829559       40.692406       -73.745216
# 9998         18180.0  40.862228  -73.890442       40.877934       -73.866585
# 9999         18180.0  40.704906  -73.793304       40.784149       -73.845505
#
#       VehicleLocation.Latitude  VehicleLocation.Longitude  DistanceFromStop  \
# 0                    40.635170                 -73.960803              76.0
# 1                    40.590802                 -74.158340              62.0
# 2                    40.886010                 -73.912647               5.0
# 3                    40.668002                 -73.729348             267.0
# 4                    40.868134                 -73.893032              11.0
# ...                        ...                        ...               ...
# 9995                 40.596955                 -74.069769              90.0
# 9996                 40.692326                 -73.744289             318.0
# 9997                 40.692326                 -73.744289             318.0
# 9998                 40.871502                 -73.876412             185.0
# 9999                 40.770012                 -73.826567               0.0
#
#       ExpectedArrivalTime  ScheduledArrivalTime  duration
# 0                   180.0                 374.0       0.0
# 1                   180.0               86282.0       0.0
# 2                   180.0                  53.0       0.0
# 3                   240.0                 180.0      60.0
# 4                   180.0               86378.0       0.0
# ...                   ...                   ...       ...
# 9995              18180.0               18132.0       0.0
# 9996              18240.0               15733.0      60.0
# 9997              18240.0               15625.0      60.0
# 9998              18180.0               18085.0       0.0
# 9999              18180.0               18240.0       0.0
#
# [8933 rows x 11 columns]

# %%
print(df.dtypes)
# Out:
# RecordedAtTime               float64
# OriginLat                    float64
# OriginLong                   float64
# DestinationLat               float64
# DestinationLong              float64
# VehicleLocation.Latitude     float64
# VehicleLocation.Longitude    float64
# DistanceFromStop             float64
# ExpectedArrivalTime          float64
# ScheduledArrivalTime         float64
# duration                     float64
# dtype: object

# %%
X = df.iloc[:, 0:8].values
Y = df.iloc[:, 10].values
Y
# Out:
# array([ 0.,  0.,  0., ..., 60.,  0.,  0.])

# %%
X[0]
# Out:
# array([180.      ,  40.616104, -74.031143,  40.656048, -73.907379,
#         40.63517 , -73.960803,  76.      ])

# %%
Y.shape
# Out:
# (8933,)

# %%
X.shape
# Out:
# (8933, 8)

# %%
scaler = StandardScaler()
X= scaler.fit_transform(X)
X
# Out:
# array([[-1.22280821, -1.16239472, -0.97730579, ..., -0.93302388,
#         -0.30146583, -0.2364487 ],
#        [-1.22280821, -0.85492136, -1.39596011, ..., -1.44540336,
#         -2.33698975, -0.27106871],
#        [-1.22280821,  1.77889781,  0.51539147, ...,  1.96377721,
#          0.19475862, -0.41202159],
#        ...,
#        [ 1.88498252,  0.49286052,  1.01542197, ..., -0.27296343,
#          1.92960696,  0.36198284],
#        [ 1.88498252,  1.63370995,  0.4135724 , ...,  1.796233  ,
#          0.5681429 ,  0.03309278],
#        [ 1.88498252, -0.15355492,  1.37381522, ...,  0.62418571,
#          1.08177168, -0.42438588]])

# %%
X = torch.tensor(X)
Y = torch.tensor(Y)
X.shape
# Out:
# torch.Size([8933, 8])

# %%
Y.shape
# Out:
# torch.Size([8933])

# %%
n_samples = X.shape[0]
n_val = int(0.2 * n_samples)

shuffled_indices = torch.randperm(n_samples)

train_indices = shuffled_indices[:-n_val]
val_indices = shuffled_indices[-n_val:]

train_X = X[train_indices]
train_Y = Y[train_indices]
train_Y = train_Y.unsqueeze(1)

val_X = X[val_indices]
val_Y = Y[val_indices]
val_Y = val_Y.unsqueeze(1)

# %%
print(train_X.shape)
print(train_Y.shape)
print(val_X.shape)
print(val_Y.shape)
# Out:
# torch.Size([7147, 8])
# torch.Size([7147, 1])
# torch.Size([1786, 8])
# torch.Size([1786, 1])

# %%
train_X = train_X.float()
train_Y = train_Y.float()
val_X = val_X.float()
val_Y = val_Y.float()
print(train_X.dtype)
print(train_Y.dtype)
print(val_X.dtype)
print(val_Y.dtype)
# Out:
# torch.float32
# torch.float32
# torch.float32
# torch.float32

# %%
model = nn.Sequential(
            nn.Linear(8, 40), 
            nn.ReLU(),
            nn.Linear(40, 30),
            nn.ReLU(),
            nn.Linear(30, 20),
            nn.ReLU(),
            nn.Linear(20, 10),
            nn.ReLU(),
            nn.Linear(10, 5),
            nn.ReLU(),
            nn.Linear(5, 1))

model
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=40, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=40, out_features=30, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=30, out_features=20, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=20, out_features=10, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=10, out_features=5, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_X, val_X, train_Y, val_Y):
    
    for epoch in range(1, n_epochs + 1):
        train_t_p = model(train_X) 
        train_loss = loss_fn(train_t_p, train_Y)
                             
        val_t_p = model(val_X) 
        val_loss = loss_fn(val_t_p, val_Y)
        
        optimizer.zero_grad()
        train_loss.backward() 
        optimizer.step()

        if epoch ==1 or epoch % 500==0:
            print(f"Epoch {epoch}, Training loss {train_loss.item():.4f},"
                  f" Validation loss {val_loss.item():.4f}")

# %%
optimizer= optim.Adam(model.parameters(), lr=1e-4)

training_loop(
    n_epochs=20000,
    optimizer= optimizer,
    model=model,
    loss_fn=nn.MSELoss(),
    train_X=train_X,
    val_X= val_X,
    train_Y= train_Y,
    val_Y= val_Y)
# Out:
# Epoch 1, Training loss 4267.8086, Validation loss 4118.2407
# Epoch 500, Training loss 4123.4106, Validation loss 3974.0981
# Epoch 1000, Training loss 2129.1946, Validation loss 2025.3668
# Epoch 1500, Training loss 1675.8557, Validation loss 1624.4867
# Epoch 2000, Training loss 1522.1494, Validation loss 1523.7388
# Epoch 2500, Training loss 1471.8231, Validation loss 1489.6654
# Epoch 3000, Training loss 1437.9747, Validation loss 1456.4703
# Epoch 3500, Training loss 1409.3790, Validation loss 1426.9211
# Epoch 4000, Training loss 1377.9784, Validation loss 1391.8289
# Epoch 4500, Training loss 1333.5170, Validation loss 1339.3584
# Epoch 5000, Training loss 1273.8695, Validation loss 1263.2159
# Epoch 5500, Training loss 1230.1340, Validation loss 1202.8314
# Epoch 6000, Training loss 1211.4916, Validation loss 1179.9188
# Epoch 6500, Training loss 1197.4642, Validation loss 1170.6450
# Epoch 7000, Training loss 1182.3652, Validation loss 1164.2921
# Epoch 7500, Training loss 1164.8650, Validation loss 1155.3086
# Epoch 8000, Training loss 1143.8992, Validation loss 1143.5088
# Epoch 8500, Training loss 1121.0179, Validation loss 1135.6005
# Epoch 9000, Training loss 1098.3984, Validation loss 1128.6954
# Epoch 9500, Training loss 1080.2592, Validation loss 1124.8916
# Epoch 10000, Training loss 1065.3456, Validation loss 1125.5154
# Epoch 10500, Training loss 1052.4846, Validation loss 1124.8708
# Epoch 11000, Training loss 1038.8701, Validation loss 1123.7241
# Epoch 11500, Training loss 1026.0983, Validation loss 1117.5156
# Epoch 12000, Training loss 1013.3484, Validation loss 1118.1074
# Epoch 12500, Training loss 1001.6710, Validation loss 1119.9211
# Epoch 13000, Training loss 988.1180, Validation loss 1116.4393
# Epoch 13500, Training loss 974.6426, Validation loss 1115.6854
# Epoch 14000, Training loss 960.4462, Validation loss 1122.1119
# Epoch 14500, Training loss 946.7376, Validation loss 1124.0054
# Epoch 15000, Training loss 934.0376, Validation loss 1127.8385
# Epoch 15500, Training loss 922.2962, Validation loss 1133.7876
# Epoch 16000, Training loss 908.8939, Validation loss 1135.1429
# Epoch 16500, Training loss 892.9247, Validation loss 1142.1174
# Epoch 17000, Training loss 874.1802, Validation loss 1153.2291
# Epoch 17500, Training loss 854.6436, Validation loss 1167.3339
# Epoch 18000, Training loss 839.6852, Validation loss 1177.6510
# Epoch 18500, Training loss 827.1321, Validation loss 1182.3992
# Epoch 19000, Training loss 814.9805, Validation loss 1188.2178
# Epoch 19500, Training loss 802.7138, Validation loss 1197.4711
# Epoch 20000, Training loss 785.2104, Validation loss 1209.1421
